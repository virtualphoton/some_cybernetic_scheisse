# %%
import cv2.aruco as aruco

# %%
dictionary = aruco.getPredefinedDictionary(aruco.DICT_4X4_50)

# %%
board = aruco.CharucoBoard((5, 8), 0.04, 0.03, dictionary)

# %%
img = board.generateImage((1080, 1920))

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image
Image.fromarray(img).save("./board.png")

# %%
plt.imshow(img, cmap="gray")

# %%
board = aruco.ar.GridBoard_create(markersX=sizeX, markersY=sizeY, markerLength=0.04, markerSeparation=0.01, dictionary=ar_dict
# Out:
# < cv2.aruco.Dictionary 0x7f4ca6688230>
